# %% [markdown]
# <a href="https://colab.research.google.com/github/PALAKTRIPATHI05/SD_palaktripathi_0102/blob/main/generator_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonnac(n):
  a=0
  b=1
  for i in range(n):
    print(a)
    c=a+b
    a=b
    b=c

# %%
fibonnac(7)
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
def fibo(n):
  a=0
  b=1
  while True:
    print(a)
    c=a+b
    a=b
    b=c

# %%
s='sudha'

# %%
for i in s :
  print(i)
# Out:
# s
# u
# d
# h
# a

# %%
s1=iter(s)

# %%
next(s1)
# Out:
# 's'

# %%
def count(n):
  count=1
  while count<=n:
    print(count)
    count=count+1

# %%
count(3)
# Out:
# 1
# 2
# 3
