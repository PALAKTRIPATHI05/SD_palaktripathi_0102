# %% [markdown]
# <a href="https://colab.research.google.com/github/PALAKTRIPATHI05/SD_palaktripathi_0102/blob/main/mini_project_atm_stimulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def withdraw():
  cardno = input('enter the card no.')
  if cardno.isdigit():
    print('card no. validate')
    print('services')
    print('1.cash withdraw')
    print('2.check balance')
    print('3.cancel transaction')
    print('4.cash deposit')
    print('5. pin changes')
    print('6.fund transfer')
  choice= int(input('enter your choice '))
  if choice == 1:
   amount=int(input('enter the amount'))
  pin=input('please enter your pin')
  if pin.isdigit():
    print('transaction complete')
    print('thanku')
def pinupdate():
  cardno=int(input('enter your your choice'))

  print('card no. validate')
  print('services')
  print('1.cash withdraw')
  print('2.check balance')
  print('3.cancel transaction')
  print('4.cash deposit')
  print('5. pin changes')
  print('6.fund transfer')

  pin= int(input('enter the current pin'))
  npin=int(input('enter the new pin'))
  print('it changed successfully')
def balance():
    cardno = input('enter the card no.')
    if cardno.isdigit():
     print('card no. validate')
     print('services')
     print('1.cash withdraw')
     print('2.check balance')
     print('3.cancel transaction')
     print('4.cash deposit')
     print('5. pin changes')
     print('6.fund transfer')
     choice= int(input('enter your choice '))


     if choice==2 :
        print('balance is xxx00 ')
     else:
       print('thanku')

# %%
def withdraw():
  cardno = input('enter the card no.')
  if cardno.isdigit():
    print('card no. validate')
    print('services')
    print('1.cash withdraw')
    print('2.check balance')
    print('3.cancel transaction')
    print('4.cash deposit')
    print('5. pin changes')
    print('6.fund transfer')
  choice= int(input('enter your choice '))
  if choice == 1:
   amount=int(input('enter the amount'))
  pin=input('please enter your pin')
  if pin.isdigit():
    print('transaction complete')
    print('thanku')
def pinupdate():
  cardno=int(input('enter your your choice'))

  print('card no. validate')
  print('services')
  print('1.cash withdraw')
  print('2.check balance')
  print('3.cancel transaction')
  print('4.cash deposit')
  print('5. pin changes')
  print('6.fund transfer')
  choice=int(input('enter your choice'))
  pin= int(input('enter the current pin'))
  npin=int(input('enter the new pin'))
  print('it changed successfully')
def balance():

 if choice==2 :
  print('balance is xxx00 ')
 else:
  print('thanku')

# %%
withdraw()
# Out:
# enter the card no.45
# card no. validate
# services
# 1.cash withdraw
# 2.check balance
# 3.cancel transaction
# 4.cash deposit
# 5. pin changes
# 6.fund transfer
# enter your choice 1
# enter the amount87
# please enter your pin56
# transaction complete
# thanku

# %%
pinupdate()
# Out:
# enter your your choice65
# card no. validate
# services
# 1.cash withdraw
# 2.check balance
# 3.cancel transaction
# 4.cash deposit
# 5. pin changes
# 6.fund transfer
# enter the current pin7666666
# enter the new pin12333
# it changed successfully
