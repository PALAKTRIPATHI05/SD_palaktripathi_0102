# %% [markdown]
# <a href="https://colab.research.google.com/github/PALAKTRIPATHI05/SD_palaktripathi_0102/blob/main/day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
m= [1,2,3.4,'palak']

# %%
m[2].real
# Out:
# 3.4

# %%
m[0:4:2]
# Out:
# [1, 3.4]

# %%
type(m)
# Out:
# list

# %%
m[1]
# Out:
# 2

# %%
m[-1:-4:-4]
# Out:
# ['palak']

# %%
m[-1]
# Out:
# 'palak'

# %%
s='palak'

# %%
list(s)
# Out:
# ['p', 'a', 'l', 'a', 'k']

# %%
list(s)+m
# Out:
# ['p', 'a', 'l', 'a', 'k', 1, 2, 3.4, 'palak']

# %%
m[3][2]
# Out:
# 'l'

# %%
type(m[3])
# Out:
# str

# %%
len(m)
# Out:
# 4

# %%
m.append(s)

# %%
m
# Out:
# [1, 2, 3.4, 'palak', 'palak']

# %%
m.extend('palak')

# %%
m
# Out:
# [1, 2, 3.4, 'palak', 'palak', 'p', 'a', 'l', 'a', 'k', 'p', 'a', 'l', 'a', 'k']

# %%
m.remove(2)

# %%
m
# Out:
# [1, 3.4, 'palak', 'palak', 'p', 'a', 'l', 'a', 'k', 'p', 'a', 'l', 'a', 'k']

# %%
m.reverse()

# %%
m
# Out:
# ['k', 'a', 'l', 'a', 'p', 'k', 'a', 'l', 'a', 'p', 'palak', 'palak', 3.4, 1]

# %%
j=[1,4,3,7,6]

# %%
j.sort()

# %%
j
# Out:
# [1, 3, 4, 6, 7]

# %%
s.replace('palak','paalak')
# Out:
# 'paalak'

# %%
s
# Out:
# 'palak'

# %%
t=(2,5,4,5,7,'palak')

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 6

# %%
t.append(hope)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_556/3522904787.py in <cell line: 0>()
# ----> 1 t.append(hope)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.pop(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_556/2490180908.py in <cell line: 0>()
# ----> 1 t.pop(2)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t*3
# Out:
# (2, 5, 4, 5, 7, 'palak', 2, 5, 4, 5, 7, 'palak', 2, 5, 4, 5, 7, 'palak')

# %%
s={}

# %%
type(s)
# Out:
# dict

# %%
s2={1,3,4,5,}

# %%
type(s2)
# Out:
# set

# %%
s2.pop()
# Out:
# 1

# %%
s2
# Out:
# {3, 4, 5}

# %%
s2.delete(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_556/1381592707.py in <cell line: 0>()
# ----> 1 s2.delete(3)
#
# AttributeError: 'set' object has no attribute 'delete'

# %%
d={'key':'palak'}

# %%
type(d)
# Out:
# dict

# %%
d
# Out:
# {'key': 'palak'}

# %%
d1={'name':'plak','age':12,'hobby':'kuchbhi'}

# %%
d1
# Out:
# {'name': 'plak', 'age': 12, 'hobby': 'kuchbhi'}

# %%
d1['name']
# Out:
# 'plak'

# %%
 rollno =int(input('enter your roll no.input'))
 marks=int(input('enter your percentage'))
 if marks>=80:
  print('you are in A ')
 else :
  print('you are in B')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_556/2274699098.py in <cell line: 0>()
# ----> 1 rollno =int(input('enter your roll no.input'))
#       2 marks=int(input('enter your percentage'))
#       3 if marks>=80:
#       4  print('you are in A ')
#       5 else :
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
 rollno =int(input('enter your roll no.input'))
 dbmsmarks=int(input('enter your percentage'))
 csmarks= int(input('enter cs marks'))
 itmarks=int(input('enter it marks'))
 if dbmsmarks>=90 and csmarks>=90 and itmarks>=90:
  print('you are in A ')
 else :
  print('you are in B')
# Out:
# enter your roll no.input45
# enter your percentage67
# enter cs marks89
# enter it marks90
# you are in B

# %%
 rollno =int(input('enter your roll no.input'))
 dbmsmarks=int(input('enter your percentage'))
 if dbmsmarks>90:
  print('A')
 else:
  print('B')
 csmarks= int(input('enter cs marks'))
 if csmarks>90:
  print('A')
 else:
    print('b')
 itmarks=int(input('enter it marks'))
 if itmarks>=90:
  print('you are in A ')
 else :
  print('you are in B')
# Out:
# enter your roll no.input23
# enter your percentage92
# A
# enter cs marks67
# b
# enter it marks87
# you are in B

# %%
l=[1,2,3,'aish','cash',2.3]

# %%
li_num=[]
l2_str=[]
for i in l:
  if type(i)==int or type(i)==float:
    li_num.append(i)
  else:
    l2_str.append(i)

# %%
li_num
# Out:
# [1, 2, 3, 2.3]

# %%
l2_str
# Out:
# ['aish', 'cash']

# %%
loo=[1,2,3,4,'yoossss',3.33,True,]

# %%
li_num=[]
l2_str=[]
l3_float=[]
l4_bool=[]
for i in l:
  if type(i)==int:
    li_num.append(i)
  elif type(i)==float:
    l3_float.append(i)
  elif type(i)==str:
    l2_str.append(i)
  else:
    l4_bool.append(i)

# %%
li_num
# Out:
# [1, 2, 3]

# %%
i
nput('enter the number of your choice')
if num==num[::-1]:
  print('its palindrome')
else:
  print('its not palindrome')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9714/4010190745.py in <cell line: 0>()
# ----> 1 input('enter the number of your choice')
#       2 if num==num[::-1]:
#       3   print('its palindrome')
#       4 else:
#       5   print('its not palindrome')
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
alpha= input('enetr the no. of your choice')
rev=''
for i in alpha:
  rev= rev + i
  if rev == alpha:
    print('its palindrome')
  else:
    print('its not')
# Out:
# enetr the no. of your choice121
# its not
# its not
# its palindrome

# %%
l=[1,2,3,4,5,60]
sum=0
for i in l:
  sum=sum+i
  print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 75

# %%
sum=0
for i in l:
  if i%2==0:
    sum=sum+i
    print(sum)
# Out:
# 2
# 6
# 66

# %%
dict={'name':'riva','age':'24'}
keys=[]
values=[]
for item in dict.items():
  keys.append(item[0]),values.append(item[1])
  print(keys)
  print(values)
# Out:
# ['name']
# ['riva']
# ['name', 'age']
# ['riva', '24']
