# %% [markdown]
# <a href="https://colab.research.google.com/github/PALAKTRIPATHI05/SD_palaktripathi_0102/blob/main/dayyy_3_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[1,3,9]

# %%
for i in l :
  i(0)==1
  i(1)==9
  i(2)==8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2419/1709244106.py in <cell line: 0>()
#       1 for i in l :
# ----> 2   i(0)==1
#       3   i(1)==9
#       4   i(2)==8
#
# TypeError: 'int' object is not callable

# %%
l1=[]
for i in  l:
  l1.append(i**2)

# %%
l1
# Out:
# [1, 9, 81]

# %%
di={'name':'34','age':'12'}

# %%
for i in l:
  if i%2==0:
   print(i)

# %%
di1={}
for k,v in di.items():
  di1[k]= int(v)**2
  print(di1)
# Out:
# {'name': 1156}
# {'name': 1156, 'age': 144}

# %%
di2={}
for k,v in di.items():
  if int(v)>1:

   print(k,v)
# Out:
# name 34
# age 12

# %%
def add(a,b):
  m=a+b
  print(m)

a=1
b=4
add(a,b)
# Out:
# 5

# %%
def test1():
  print('very very beautiful')

# %%
def test():
  return ' hello guys'

# %%
test()
# Out:
# ' hello guys'

# %%
test()+'kaise hoo'
# Out:
# ' hello guyskaise hoo'

# %%
def test3 ():
  return' yoo guys'

# %%
test3()
# Out:
# ' yoo guys'

# %%
def test5(a,b):
  return a*b

# %%
test5(5,70)
# Out:
# 350

# %%
def test4(a,b):
 return a+b

# %%
test4('hii','sorry')
# Out:
# 'hiisorry'

# %%
def test9(*args):
  return args+ (1,2,3)

# %%
type(test9())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2419/3128308652.py in <cell line: 0>()
# ----> 1 type(test9())
#
# /tmp/ipykernel_2419/806961473.py in test9(*args)
#       1 def test9(*args):
# ----> 2   return args+ [1,2,3]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test7(*kwargs):
  return kwargs+(1,1,2)

# %%
type(test7())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2419/727687955.py in <cell line: 0>()
# ----> 1 type(test7())
#
# /tmp/ipykernel_2419/4145068682.py in test7(*kwargs)
#       1 def test7(*kwargs):
# ----> 2   return kwargs+[1,1,2]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test8(*sudh):
  return sudh

# %%
test8(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test11(*args,a):
  return args,a

# %%
test11(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2419/319663502.py in <cell line: 0>()
# ----> 1 test11(1,2,3,4)
#
# TypeError: test11() missing 1 required keyword-only argument: 'a'

# %%
test11(1,2,3,4,a=4)
# Out:
# ((1, 2, 3, 4), 4)

# %%
def test12(c,d,b=1,a=5):
  return a,b,c,d

# %%
test12(3,4)
# Out:
# (5, 1, 3, 4)

# %%
def add(a,b):
  return a+b
def sub(a,b):
  return a-b
def multi(a,b):
  return a*b
def divide(a,b):
  if b==0:
    return 'no division possible'
  else:
    return a/b

# %%
multi(3,4)
# Out:
# 12

# %%
cardno = input('enter the card no.')
if cardno.isdigit():
  print('card no. validate')
  print('services')
  print('1.cash withdraw')
  print('2.check balance')
  print('3.cancel transaction')
  print('4.cash deposit')
  print('5. pin changes')
  print('6.fund transfer')
choice= int(input('enter your choice '))
if choice == 1:
  amount=int(input('enter the amount'))
  pin=input('please enter your pin')
  if pin.isdigit():
    print('transaction complete')
    print('thanku')
elif choice == 5:
  pin= int(input('enter the current pin'))
  npin=int(input('enter the new pin'))
  print('it changed successfully')
elif choice==2:
  print('balance is xxx00 ')
else:
  print('thanku')
# Out:
# enter the card no.345
# card no. validate
# services
# 1.cash withdraw
# 2.check balance
# 3.cancel transaction
# 4.cash deposit
# 5. pin changes
# 6.fund transfer
# enter your choice 1
# enter the amount4500
# please enter your pin765
# transaction complete
