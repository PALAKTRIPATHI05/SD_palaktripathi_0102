# %% [markdown]
# <a href="https://colab.research.google.com/github/PALAKTRIPATHI05/SD_palaktripathi_0102/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [1,2,3]

# %%
nums[0]
# Out:
# 1

# %%
list = [20,30,45,46,67,78,89,90,"palak"]

# %%
list[8]
# Out:
# 4

# %%
list = [ 2,45,4.5,"palak",23,1,2,3,4,"us"]

# %%
list[0:11:2]
# Out:
# [2, 4.5, 23, 2, 4]

# %%
list[::2]
# Out:
# [2, 4.5, 23, 2, 4]

# %%
list[::-1]
# Out:
# ['us', 4, 3, 2, 1, 23, 'palak', 4.5, 45, 2]

# %%
list[1:6:-2]
# Out:
# []

# %%
list[-1:-11:-9]
# Out:
# ['us', 2]

# %%
list.append(67)
list
# Out:
# [2, 45, 4.5, 'palak', 23, 1, 2, 3, 4, 'us', 67]

# %%
list.pop(2)
# Out:
# 4.5

# %%
list
# Out:
# [2, 45, 'palak', 23, 1, 2, 3, 4, 'us', 67]

# %%
s= {"palak","us"}

# %%
list(s)+list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1581/3228641260.py in <cell line: 0>()
# ----> 1 list(s)+list
#
# TypeError: 'list' object is not callable

# %%
Lis= [1,2,3]

# %%
st= {"palak"}

# %%
list(st)+Lis
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1581/3450906309.py in <cell line: 0>()
# ----> 1 list(st)+Lis
#
# TypeError: 'list' object is not callable

# %%
list
# Out:
# [2, 45, 'palak', 23, 1, 2, 3, 4, 'us', 67]

# %%
Lis
# Out:
# [1, 2, 3]

# %%
list[2][0:2]
# Out:
# 'pa'

# %%
list.append("true")

# %%
str(list[10][0:2])
# Out:
# 'tr'

# %%
str
# Out:
# str

# %%
st
# Out:
# {'palak'}

# %%
str= "palak","us"

# %%
list(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1581/553793963.py in <cell line: 0>()
# ----> 1 list(str)
#
# TypeError: 'list' object is not callable

# %%
list.insert(2,'67')

# %%
list
# Out:
# [2, 45, '67', 'palak', 23, 1, 2, 3, 4, 'us', 67, 'true']

# %%
a= input()
# Out:
# 'palak'

# %%
age=int(input())
# Out:
# 19

# %%
print("name=",a)
# Out:
# name= 'palak'

# %%
X="10"

# %%
Y= int(X)

# %%
print(Y)
# Out:
# 10

# %%
x='3.14'

# %%
y=float(x)

# %%
print(y)
# Out:
# 3.14

# %%
b=(1,2,3)
a= list(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1581/1398333030.py in <cell line: 0>()
#       1 b=(1,2,3)
# ----> 2 a= list(x)
#
# TypeError: 'list' object is not callable
